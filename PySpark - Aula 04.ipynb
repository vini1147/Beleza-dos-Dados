# %%
df_csv = (
    spark.read.csv("/Volumes/workspace/default/beleza_dos_dados/f_atendimento.csv"
        ,header=True
        ,inferSchema=True
    )
)

# %%
df_csv.display()

# %%
df_csv.write.mode("overwrite").csv("/Volumes/workspace/default/beleza_dos_dados/Aula_04.csv")
